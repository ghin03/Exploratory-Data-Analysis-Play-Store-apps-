# %% [markdown]
# <a href="https://colab.research.google.com/github/ghin03/Exploratory-Data-Analysis-Play-Store-apps-/blob/main/(EDA)Exploratory_Data_Analysis_Play_Store_apps_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Reviews Analysis

# %% [markdown]
# ##### **Project Type**    - EDA (Exploratory Data Analysis)
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Geeta Rani

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# To improve the general quality and performance of the app in the marketplace and to facilitate data-driven decision-making, exploratory data analysis (EDA) is crucial for comprehending, analyzing, and drawing insights from Play Store data.The aim of this experiment is to provide valuable insights to enhance the understanding of client wants and aid product developers in popularizing their product. For my analysis, I'll utilize the following two datasets:  Play Store data and User Reviews.
# Here's a concise summary of the data analysis process:
# 1. Data Cleaning:
# I have to clean the data to remove missing value and duplicate values such as duplicate reviews.
# 2. Data Preprocessing: I have to convert all variables into appropriate datatypes and exclude any undesired values from the numerical columns, such as "$" from the price and "+" and "," from the installs. I have to convert all the numbers in MB because the size column contains both KB and MB values.
# 3. Exploratory Data Analysis: After data cleaning and preprocessing i have to perform the EDA to find out any relation between variables and pattern or trend. For that purpose, i have to calculate summary statistics (mean, median, standard deviation, etc.) for numerical features and use density plots, box plots, or histograms to display the distributions of the characteristics.
# Use frequency counts and visual aids like bar graphs to investigate categorical variables, such as app categories.
# Use heatmaps, correlation matrices, or scatter plots to analyze relationships between variables.
# 4. Insights and Conclusion: After EDA is completed, I have to list the main conclusions and takeaways from the EDA process.
# Based on the analysis's findings, offer developers, marketers, and other stakeholders concrete suggestions.
# Draw attention to noteworthy correlations, trends, or user feelings that may have an effect on choices.
# 5.Visualization with Tableau: Tableau's interactive dashboards were used to bring the cleaned data to life. After EDA is completed, I have to list the main conclusions and takeaways from the EDA process. Based on the analysis's findings, offer developers, marketers, and other stakeholders concrete suggestions. Draw attention to noteworthy correlations, trends, or user feelings that may have an effect on choices.
#
# To sum up, this EDA will investigate, comprehend, and extract insights from Play Store data. This allows for data-driven decision-making, which in turn improves the general caliber and effectiveness of apps available for download.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ghin03/Play-Store-Data-analysis-using-Tableau.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# By analyzing and visualizing these crucial points, the experiment seeks to use Tableau's visual analytics capabilities to better understand customer needs and assist product creators in popularizing their creations.
#
# 1.Which app categories comprise the greatest quantity of apps?
#
# 2.Which app categories get more reviews than others?
#
# 3.What percentage of all apps are free?
#
# 4.What age group has rated the apps the most?
#
# 5.Top five categories determined by total income
#
# 6.Category-based Sentiment Analysis

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Enhancing user happiness, promoting business growth, and optimizing the app's overall performance in the marketplace are the ultimate objectives of investigating and evaluating app engagement data.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
playstore_data = pd.read_csv("/content/drive/MyDrive/Play Store Data.csv")
playstore_data
#Print the data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#First 10 rows of Dataset
playstore_data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
#last 10 rows of Dataset
playstore_data.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
playstore_data.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
playstore_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(playstore_data[playstore_data.duplicated()])
# Out:
# 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(playstore_data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(playstore_data.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Rating column has 1474 missing values.One value is absent from the Type column.The Content Rating column has one missing value. Eight values are absent in current ver column. Three values are absent from the Android Ver column.
# There are therefore rows in the dataset where the values in these columns are missing, which can have an impact on the analysis or modeling. Handling these missing values correctly is crucial.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
playstore_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ## **Variables Description**

# %% [markdown]
# The dataset comprises 13 columns, which are denoted as follows:
#
# 1.App - Name of the application.
#
# 2.Category - Category of the application.
#
# 3.Rating - Rating given by the users.
#
# 4.Reviews - Reviews given by the users.
#
# 5.Size - The size of the application.
#
# 6.Installs - How many installation are done.
#
# 7.Type - The application is free or paid.
#
# 8.Price - The price of the app.
#
# 9.Content Rating - Which age group finds it suitable?
#
# 10.Genres - the different additional categories.
#
# 11.Last Updated - When the application was last updated.
#
# 12.Current Ver - Current version of the application.
#
# 13.Android Ver - suitable Android version for the Application.

# %%
# Dataset Describe
playstore_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in playstore_data.columns:
    unique_values = playstore_data[column].unique()
    print(f"Unique values for {column}: {unique_values}")
# Out:
# Unique values for App: ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# Unique values for Category: ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# Unique values for Rating: [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling - Play store Data

# %%
# Write your code to make your dataset analysis ready.
#Analysing rating variable by creating boxplot
playstore_data.boxplot()
# Out:
# <Axes: >

# %%
#Handling outlier and missing values in rating variable
playstore_data[(playstore_data['Rating'] <1) | (playstore_data['Rating']>5)]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# The value 19 here in this row is an outlier also there are missing values present in this row. So we need to drop this row.

# %%
#Dropping the 10472th row from the data.
playstore_data.drop(10472,axis=0,inplace=True)
#Checking if the row is removed from the dataset.
#desired_row = playstore_data.loc[10472]
#print(desired_row)
playstore_data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# There are 1474 missing values present in this column. We need to handle them also.

# %%
#Finding the mean and median values in the values under rating variable.
rating_mean = playstore_data['Rating'].mean()
print(f"The mean of Rating column is {rating_mean}")

rating_median = playstore_data['Rating'].median()
print(f"The median of Rating column is {rating_median}")
# Out:
# The mean of Rating column is 4.191757420456972
# The median of Rating column is 4.3

# %% [markdown]
# There is not much difference between mean and median values. So, we can replace it with median value.

# %%
# filling all the null values in Rating column by the median in Rating column of the playstore data.
playstore_data['Rating'].fillna(value=rating_median,inplace=True)
# Checking the rest missing values
print(playstore_data.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# Type has one missing value. Current ver has 8 missing values and android ver has 2 missing values.

# %%
# checking the Type's NaN value in Type column of play store data
playstore_data[(playstore_data['Type'].isnull())]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     4.3       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %% [markdown]
# As we can see that the price is 0 here so, its a free app. SO, we can fill that value here

# %%
#replacing the NaN value of Type
playstore_data.loc[9148,'Type']='Free'

# %%
#Let's check if the missing value  is filled
playstore_data[(playstore_data['Type'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# We saw that There are 8 missing values present in current ver app now we will fix that.

# %%
# Current Ver's missing values in play store data
playstore_data[(playstore_data['Current Ver'].isnull())]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     4.3       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     4.3      44
# 7730                            UFO-CQ                TOOLS     4.3       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %% [markdown]
# Here we cant find any value to fill the NaN values so we need to drop these rows from the playstore data.

# %%
# Let's drop all the NaN values of Current Ver column from play store data
playstore_data.drop([15,1553,6322,6803,7333,7407,7730,10342],axis=0,inplace=True)
 #Time to check if all the Nan values are droped or not
playstore_data[(playstore_data['Current Ver'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# There are 2 missing values present in Android Ver variable. we need to fix that also.

# %%
# checking the Android Ver's NaN values
playstore_data[(playstore_data['Android Ver'].isnull())]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %% [markdown]
# Now we need to drop these rows because we cant find any suitable values to fill here

# %%
# Let's drop the NaN values of Android Ver column from play store data
playstore_data.drop([4453,4490],axis=0,inplace=True)
# checking whether these Nan values are droped or not
playstore_data[(playstore_data['Android Ver'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# Now since all missing values in each column are handeled. Its time to standardize all the values in each column.

# %%
# Let's check the values under the size column
playstore_data['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10830, dtype: object

# %% [markdown]
# We can see "Size" column has different units. Some are in MB and others are  in KB. so, we need to convert them into single unit.

# %%
# cleaning and converting 'Size' to numeric
def clean_size(x):
    if 'Varies with device' in str(x):
        return np.nan
    elif 'k' in str(x):
        return float(str(x).replace('k', '')) / 1024
    else:
        return float(str(x).replace('M', ''))


playstore_data['Size'] = playstore_data['Size'].apply(clean_size)

# %%
# checking the values in Price column in play store data
playstore_data['Price'].value_counts()
# Out:
# 0         10033
# $0.99       146
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# We can see that in some value $ sign is present while in other its not present. SO, We need to remove this sign to standersize the values.

# %%
# remove dollar sign from Price
def remove_from_price(value):
    if type(value) == str and '$' in value:
        value = value.replace('$', '')
    return value

playstore_data['Price'] = playstore_data['Price'].apply(remove_from_price)

# %%
#checking the values in Installs column in play_store_data
playstore_data['Installs'].value_counts()
# Out:
# 1,000,000+        1578
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1052
# 1,000+             905
# 5,000,000+         752
# 100+               718
# 500,000+           538
# 50,000+            478
# 5,000+             476
# 100,000,000+       409
# 10+                385
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %% [markdown]
# In this "Installs" we have to remove these signs: +(plus) and ,(comma)

# %%
#remove +(plus) and ,(comma) from Installs
def remove_from_install(values):
    if type(values) == str:
        values = values.replace(',', '').replace('+', '')
    return values

playstore_data['Installs'] = playstore_data['Installs'].apply(remove_from_install)

# %%
#converting 'Installs' to numeric data type
playstore_data['Installs'] = playstore_data['Installs'].replace('[^\d]', '', regex=True).astype(float)

# %%
#converting 'Reviews' to numeric data type
playstore_data['Reviews'] = playstore_data['Reviews'].astype(float)

# %%
# converting 'Price' to numeric data type
playstore_data['Price'] = playstore_data['Price'].replace('[^\d\.]', '', regex=True).astype(float)

# %%
#Let's check the duplicate value in "App" column in play store data
playstore_data['App'].duplicated().sum()
# Out:
# 1181

# %%
# dropping duplicates value in "App" column from play store data
playstore_data.drop_duplicates(subset='App',inplace=True)

# %%
from google.colab import files
playstore_data.to_csv('filename.csv')
files.download('filename.csv')

# %% [markdown]
# •All the missing values are handled.
# •All columns values are standerdized by removing unwanted characters and converted in suitable datatypes.•All duplicated values have been handled.

# %% [markdown]
# ## ** Data Wrangling - User Review Data

# %%
#Importing the User Reviews File from Google Drive as user_reviews_data
userreviews_data = pd.read_csv('/content/drive/MyDrive/User Reviews.csv')
userreviews_data
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
# checking the number of rows and columns  of user reviews data
userreviews_data.shape
# Out:
# (64295, 5)

# %%
# checking the columns of user reviews data
userreviews_data.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset has 5 columns described below:
#
# *   App: Name of the application.
# *   Translated_Review: English translation of the review.
# *   Sentiment: Emotion like ‘Positive’, ‘Negative’, or ‘Neutral’.
# *   Sentiment_Polarity:  Polarity of the review (ranges [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’).
# *   Sentiment_Subjectivity: How close a reviewers opinion is to the opinion of the general public. Its range is[0,1].

# %%
# Checking info of user reviews data
userreviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# finding the Null values of Sentiment_Polarity column in user_reviews_data
userreviews_data[(userreviews_data['Sentiment_Polarity'].isnull())]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %% [markdown]
# We can observe that the rows in which the column "sentiment_polarity" has null values  mostly all other columns also have null values. SO, we can drop those rows.

# %%
# droping all null values from user_reviews_data
userreviews_data.dropna(inplace = True)
userreviews_data
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
from google.colab import files
userreviews_data.to_csv('filename.csv')
files.download('filename.csv')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. To verify the data type of each variable, we first obtained information about the play store data. We examined each column for duplicate values and missing values. To standardize the data, we examined each column for undesired units or characters. We eliminated 483 duplicate values that we discovered. The median value was used to replace the 1474 null values that we discovered in the "Rating" column. Additionally, we eliminated an anomaly with a value of 19 from the rating column since we verified that the highest possible rating is 5. Eight null entries from the "Current Ver" column, two null values from the "Android Ver" column, and one null value from the "Type" column were removed.
# We discovered that 10,039 free apps had a price of 0, thus for clarity, we substituted the term "Free" for the pricing value. To make the data more readable and consistent, we eliminated superfluous characters like "+" and "," from the "Installs" column, "$" sign from the "Price" column, and "M" and "K" from the "Size" column. In order to prevent duplication and guarantee data accuracy, we identified 1181 duplicate apps in the "App" column and eliminated them.
# 2. Data wrangling on User Review Data
# In order to verify the data type of each variable, we first obtained information on the User Review data. We investigated the data for any missing values. Since the values in the "Sentiment_Polarity" column were categorical and could not be imputed with a value, we used dropna to remove all null values from the dataset.
#
# We discovered these insights from the above manipulations.
#
# Based on the play_store_data, we discovered that over 10039 apps are available for free, while only 800 are paid for. We also eliminated 1181 duplicate app items from the dataset. Additionally, we found that there were 1474 missing data in the Rating column. We replaced them with the median value. In addition, we eliminated 483 redundant rows.
#
# Additionally, We discovered that the user reviews data collection has 5 columns and 64295 rows. Since the values in the "Sentiment Polarity" column were categorical, we removed the few missing values that we found.
#
# As a conclusion, we can state that the user reviews and play store statistics are valuable datasets and now our data has been cleaned and standardised for future analysis purposes.

# %% [markdown]
# **Tableau Dashboard Link**

# %% [markdown]
# https://public.tableau.com/views/Analysisstoryofplaystoredata/Story1?:language=en-US&publish=yes&:sid=&:display_count=n&:origin=viz_share_link
